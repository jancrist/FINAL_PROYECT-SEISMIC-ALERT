# %%
import pandas as pd

# %%
df = pd.read_csv('Salida.csv')

# %%
df.head(2)
# Out:
#    0  1950-01-30T01:34:11.520Z  33.6956667  -118.3898333    6.0  2.41  ml  \
# 0  1  1950-01-30T00:56:35.020Z  -53.472000    -71.073000  15.00  6.80  mw
# 1  2  1950-01-29T05:21:16.030Z   34.000833   -117.568167   0.54  2.52  ml
#
#    5.0  277.0  0.4868  ...  2016-01-28T17:58:15.530Z  \
# 0  NaN    NaN     NaN  ...  2022-04-26T18:23:21.977Z
# 1  8.0  121.0  0.1603  ...  2016-01-28T18:12:06.570Z
#
#    5km S of Rancho Palos Verdes, CA  earthquake   1.9  31.61  0.146  6.0.1  \
# 0  36 km SSW of Punta Arenas, Chile  earthquake   NaN  25.00  0.200    NaN
# 1            5km W of Mira Loma, CA  earthquake  0.88   2.16  0.253    8.0
#
#    reviewed    ci.1    ci.2
# 0  reviewed  iscgem  iscgem
# 1  reviewed      ci      ci
#
# [2 rows x 23 columns]

# %%
df.columns = ['fuera','time','latitude','longitude','depth','mag','magType','nst','gap','dmin','rms','net','id','updated','place','type','horizontalError','depthError','magError','magNst','status','locationSource','magSource']

# %%
pd.options.display.max_columns = 0
df.head(2)
# Out:
#    fuera                      time  ...  locationSource  magSource
# 0      1  1950-01-30T00:56:35.020Z  ...          iscgem     iscgem
# 1      2  1950-01-29T05:21:16.030Z  ...              ci         ci
#
# [2 rows x 23 columns]

# %%
fila = {'fuera' : '0', 'time' : '1950-01-30T01:34:11.520Z', 'latitude' : '33.6956667', 'longitude' : '-118.3898333',
       'depth' : '6.0', 'mag' : '2.41', 'magType' : 'ml', 'nst' : '5.0', 'gap' : '277.0', 'dmin' : '0.4868',
       'rms' : '0.38', 'net' : 'ci', 'id' : 'ci3362482', 'updated' : '2016-01-28T17:58:15.530Z',
       'place' : '5km S of Rancho Palos Verdes, CA', 'type' : 'earthquake', 'horizontalError' : '1.9', 'depthError' : '31.61',
       'magError' : '0.146','magNst' : '6.0.1','status' : 'reviewed','locationSource' : 'ci.1', 'magSource' : 'ci.2'}

# %%
df = df.append(fila, ignore_index = True)
# Out:
# C:\Users\juseb\AppData\Local\Temp\ipykernel_4372\3261263708.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(fila, ignore_index = True)

# %%
#df['time'] = pd.to_datetime(df.time, errors = 'coerce')
df
# Out:
#          fuera                      time  ... locationSource magSource
# 0            1  1950-01-30T00:56:35.020Z  ...         iscgem    iscgem
# 1            2  1950-01-29T05:21:16.030Z  ...             ci        ci
# 2            3  1950-01-28T22:45:12.670Z  ...             ci        ci
# 3            4  1950-01-28T22:36:21.460Z  ...             ci        ci
# 4            5  1950-01-28T12:10:04.690Z  ...             ci        ci
# ...        ...                       ...  ...            ...       ...
# 4101615  12925  2022-09-01T00:19:05.510Z  ...             nc        nc
# 4101616  12926  2022-09-01T00:06:22.711Z  ...             ak        ak
# 4101617  12927  2022-09-01T00:02:18.320Z  ...             ci        ci
# 4101618  12928  2022-09-01T00:01:27.720Z  ...             nc        nc
# 4101619      0  1950-01-30T01:34:11.520Z  ...           ci.1      ci.2
#
# [4101620 rows x 23 columns]

# %%
df.drop(['fuera'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#                        time   latitude  ... locationSource magSource
# 0  1950-01-30T00:56:35.020Z    -53.472  ...         iscgem    iscgem
# 1  1950-01-29T05:21:16.030Z  34.000833  ...             ci        ci
# 2  1950-01-28T22:45:12.670Z  35.860333  ...             ci        ci
# 3  1950-01-28T22:36:21.460Z  35.836333  ...             ci        ci
# 4  1950-01-28T12:10:04.690Z       35.7  ...             ci        ci
#
# [5 rows x 22 columns]

# %% [markdown]
# # Revisado de valores de las columnas

# %%
df['type'].unique()
# Out:
# array(['earthquake', 'quarry blast', 'nuclear explosion', 'mine collapse',
#        'other event', 'explosion', 'sonic boom', 'chemical explosion',
#        'rock burst', 'ice quake', 'rockslide', 'Rock Slide',
#        'accidental explosion', 'landslide', 'mining explosion', 'quarry',
#        'building collapse', 'acoustic noise', 'sonicboom', 'not reported',
#        'experimental explosion', 'collapse', 'meteorite',
#        'induced or triggered event', 'volcanic eruption', 'Ice Quake'],
#       dtype=object)

# %%
df['status'].unique()
# Out:
# array(['reviewed', 'automatic', 'manual'], dtype=object)

# %%
df['locationSource'].unique()
# Out:
# array(['iscgem', 'ci', 'iscgemsup', 'ushis', 'pags', 'hv', 'official',
#        'nc', 'uw', 'us', 'j', 's', 'm', 'b', 'a', 'r', 'p', 'e', 'nm',
#        'c', 'h', 'w', 'v', 'l', 'ak', 'u', 'g', 't', 'se', 'gl', 'o',
#        'ag', 'd', 'uu', 'brk', 'wes', 'pas', 'doe', 'ott', 'ren', 'slc',
#        'bla', 'tul', 'pal', 'spe', 'tei', 'pgc', 'scp', 'co', 'slm',
#        'ags', 'gcmt', 'but', 'ecx', 'bou', 'sea', 'hdc', 'hlw', 'snm',
#        'exp', 'lak', 'mac', 'cle', 'aei', 'hoj', 'aeic', 'macr', 'spec',
#        'teic', 'gen', 'guc', 'ldg', 'isk', 'mdd', 'upa', 'unm', 'mpr',
#        'str', 'trn', 'rom', 'dja', 'fbb', 'zag', 'bgs', 'bse', 'usbr',
#        'pdg', 'css', 'ath', 'gii', 'the', 'rsnc', 'fdf', 'aro', 'sko',
#        'lju', 'tva', 'sjr', 'wel', 'tap', 'casc', 'mb', 'zur', 'pre',
#        'nn', 'rspr', 'grf', 'obn', 'ryd', 'jsn', 'mel', 'ld', 'ppt',
#        'nic', 'csc', 'buc', 'mrb', 'war', 'ogso', 'ssnc', 'car', 'aust',
#        'dmn', 'indr', 'ber', 'nnc', 'lim', 'teh', 'snet', 'inmg', 'csem',
#        'sja', 'alg', 'irsa', 'gfu', 'jma', 'thr', 'sof', 'bykl', 'upp',
#        'gom', 'hel', 'nssp', 'bdf', 'dhmr', 'ceri', 'ndi', 'tri', 'tir',
#        'beo', 'dbn', 'dda', 'zamg', 'ucr', 'qui', 'bhl', 'hvo', 'sdd',
#        'ept', 'cnrm', 'bji', 'hon', 'pda', 'dnk', 'pr', 'oh', 'us_wel',
#        'us_guc', 'us_unm', 'us_isk', 'us_ott', 'us_sja', 'us_aust',
#        'us_teh', 'us_car', 'us_mdd', 'us_bgs', 'us_lim', 'us_rom',
#        'us_trn', 'us_pgc', 'us_the', 'us_ath', 'us_qui', 'us_thr',
#        'us_tul', 'us_buc', 'us_rsnc', 'us_snet', 'us_ecx', 'us_gcg',
#        'us_ldg', 'us_inmg', 'ismp', 'rey', 'pivs', 'sors', 'bgrd',
#        'ismpkansas', 'av', 'aacse', 'ok', 'tx', 'ew', 'at', 'pt', 'ci.1'],
#       dtype=object)

# %%
df['magSource'].unique()
# Out:
# array(['iscgem', 'ci', 'iscgemsup', 'brk', 'pas', 'ushis', 'official',
#        'mmt', 'sc', 'epb', 'ren', 'hvo', 'dg', 'slm', 'rot', 'upp', 'st',
#        'mos', 'mat', 'hv', 'us', 'dor', 'yel', 'th', 'pal', 'gw', 'gol',
#        'hrn', 'stt', 'dos', 'dw', 'isc', 'bak', 'bar', 'nc', 'her', 'uw',
#        'jm', 'gb', 'som', 'hrm', 'erl', 'gs', 'pmr', 'tri', 'ath', 'bns',
#        'ist', 'nm', 'csc', 'san', 'stu', 'tul', 'sea', 'bla', 'ak',
#        'erda', 'slc', 'ott', 'zur', 'mso', '01020', 'rom', 'wes', 'lao',
#        'aec', 'grc', 'sko', '01000', 'apt', 'hfs', 'isk', 'cll', 'ldg',
#        'grf', 'prt', 'tir', 'gcmt', 'fir', 'se', 'can', 'aam', 'vie',
#        'pru', 'ttg', 'lju', 'bly', 'tol', 'mhi', 'pgc', 'fur', 'war',
#        'pro', '01009', '01023', 'uu', 'sal', 'rmp', 'mns', 'kra', 'oth',
#        'cti', 'gib', 'vka', 'pre', 'kbn', 'bud', 'wel', 'gs$', 'kba',
#        'nao', 'ibk', 'scp', 'ori', 'php', 'co', 'dle', 'dmu', 'bry',
#        'dou', 'but', 'sda', 'aqu', 'bji', 'sfs', 'mox', 'vlo', 'hrv',
#        'tei', 'esk', 'dkm', 'cvf', 'brt', 'dui', 'edu', 'alp', 'srn',
#        'hcy', 'sro', 'ple', 'iva', 'nb2', 'ber', 'the', 'fdf', 'pag',
#        'mgg', 'ulc', 'pvy', 'dg$', 'riv', 'koe', 'mlg', 'stk', 'elo',
#        'voy', 'too', 'bfd', 'edi', 'css', 'rmq', 'klg', 'nau', 'knt',
#        'cms', 'new', 'ifr', 'htl', 'mdd', 'kmi', 'ecp', 'bul', 'ucc',
#        'cam', 'gcg', 'mth', 'bgs', 'crm', 'vay', 'aba', 'hdc', 'ecx',
#        'wer', 'stb', 'prl', 'trn', 'asp', 'mof', 'aro', 'ned', 'lsz',
#        'upa', 'zag', 'gzh', 'ave', 'bhl', 'jer', 'bmu', 'kuk', 'cnb',
#        'pmg', 'mte', 'alg', 'frf', 'mm4', 'sjr', 'pto', 'uvc', 'gen',
#        'qis', 'sso', 'hlw', 'str', 'jma', 'snm', 'sjs', 'beo', 'tio',
#        'fel', 'vao', 'rba', 'sva', 'par', 'teh', 'ohr', 'jck', 'taf',
#        'gsh', 'krw', 'bra', 'lic', 'pda', 'unm', 'lis', 'aei', 'gs/',
#        'ndi', 'hoj', 'qui', 'gm$', 'lmm', 'buc', 'ryd', 'qlp', 'mpr',
#        'eta', 'dda', 'gm/', 'rtc', 'bth', 'apy', 'car', 'sss', 'dbn',
#        'dmn', 'aeic', 'duputel', 'ppt', 'teic', 'rusms', 'dja', 'fbb',
#        'hyb', 'guc', 'gii', 'bse', 'pdg', 'usbr', 'ruvs', 'tva', 'rsnc',
#        'tap', 'mb', 'casc', 'nn', 'rspr', 'brg', 'aust', 'jsn', 'mel',
#        'ld', 'cig', 'csem', 'zamg', 'nic', 'ogso', 'ssnc', 'snet', 'indr',
#        'thr', 'nied', 'nnc', 'sja', 'obn', 'irsa', 'gfu', 'niec', 'bhd',
#        'meri', 'dhmr', 'sof', 'inmg', 'mrb', 'nssp', 'rey', 'lim', 'bdf',
#        'igil', 'krsc', 'skhl', 'tif', 'ucr', 'exp', 'ceri', 'sbs', 'gfz',
#        'cnrm', 'sdd', 'ept', 'azer', 'hel', 'pr', 'us_unm', 'us_isk',
#        'us_sja', 'us_guc', 'us_ott', 'us_aust', 'us_gcmt', 'us_car',
#        'us_rsnc', 'us_mdd', 'us_bgs', 'us_rom', 'us_pgc', 'us_the',
#        'us_wel', 'us_tul', 'us_buc', 'us_ucr', 'us_zamg', 'us_teh',
#        'us_ecx', 'us_lim', 'us_gcg', 'us_ldg', 'us_inmg', 'oh', 'ismp',
#        'sors', 'bgrd', 'inet', 'ismpkansas', 'spec', 'av', 'aacse', 'ok',
#        'tx', 'ew', 'at', 'pt', 'ci.2'], dtype=object)

# %%
df['magNst'].unique()
# Out:
# array([nan, 8.0, 4.0, 2.0, 6.0, 10.0, 11.0, 13.0, 5.0, 3.0, 12.0, 9.0,
#        14.0, 7.0, 0.0, 1.0, 16.0, 15.0, 20.0, 17.0, 19.0, 18.0, 24.0,
#        21.0, 23.0, 22.0, 26.0, 28.0, 25.0, 27.0, 29.0, 30.0, 35.0, 31.0,
#        33.0, 34.0, 36.0, 56.0, 39.0, 40.0, 41.0, 45.0, 32.0, 95.0, 60.0,
#        46.0, 37.0, 68.0, 82.0, 51.0, 53.0, 50.0, 49.0, 63.0, 38.0, 81.0,
#        57.0, 55.0, 52.0, 67.0, 42.0, 47.0, 43.0, 69.0, 58.0, 62.0, 64.0,
#        59.0, 70.0, 86.0, 76.0, 44.0, 54.0, 78.0, 71.0, 66.0, 72.0, 48.0,
#        89.0, 65.0, 77.0, 79.0, 87.0, 73.0, 91.0, 93.0, 85.0, 61.0, 106.0,
#        75.0, 96.0, 80.0, 74.0, 100.0, 102.0, 101.0, 99.0, 83.0, 90.0,
#        'mlg', 'mun', 'mb_lg', 'mc', 'mwc', 'Unknown', 'mblg', 'm', 'mwb',
#        'mww', 'mwr', 'Md', 'mdl', 'no', 'hn', 'Ml', 'Mb', 'me', 'ms_20',
#        'mlr', 'mwp', 'mlv', 'Mi'], dtype=object)

# %%
df.head(2)
# Out:
#                        time   latitude  ... locationSource magSource
# 0  1950-01-30T00:56:35.020Z    -53.472  ...         iscgem    iscgem
# 1  1950-01-29T05:21:16.030Z  34.000833  ...             ci        ci
#
# [2 rows x 22 columns]

# %% [markdown]
# # Creamos un nuevo dataframe con las columnas que vamos a utilizar

# %%
df_nuevo=df[['time','latitude','longitude','depth','mag','magType','nst','gap','dmin','rms','net','place','type']]

# %%
df_nuevo.head(2)
# Out:
#                        time  ...        type
# 0  1950-01-30T00:56:35.020Z  ...  earthquake
# 1  1950-01-29T05:21:16.030Z  ...  earthquake
#
# [2 rows x 13 columns]

# %% [markdown]
# Analizamos bien la columna magType

# %%
df_nuevo['magType'].unique()
# Out:
# array(['mw', 'ml', 'mh', nan, 'uk', 'fa', 'ms', 'mb', 'md', 'lg', 'ma',
#        'mlg', 'mun', 'mb_lg', 'mc', 'mwc', 'Unknown', 'mblg', 'm', 'mwb',
#        'mww', 'mwr', 'Md', 'mdl', 'no', 'hn', 'Ml', 'Mb', 'me', 'ms_20',
#        'mlr', 'mwp', 'mlv', 'Mi'], dtype=object)

# %% [markdown]
# # Cambiamos el tipo de dato a la columna mag

# %%
df_nuevo=df_nuevo.astype({'mag':'float32'})

# %% [markdown]
# # Utilizamos solo las magnitudes mayores a 1.5

# %%
mag_max_1=df_nuevo[df_nuevo['mag']>1.5]

# %% [markdown]
# Revisamos la diferencia de datos del dataset original al nuevo

# %%
#1.970.000 filas y 13 columnas
mag_max_1.shape
# Out:
# (1970471, 13)

# %%
#4 millones de filas y 22 columnas
df.shape
# Out:
# (4101620, 22)

# %% [markdown]
# # Filtramos solo los que sean earthquake

# %%
earthquake=mag_max_1[mag_max_1['type']=='earthquake']

# %%
# Consideramos que esto no considera una mejora significativa para nuestro modelo por lo que es mejor simplemente dejar esta columna y dejar los datos de esta
earthquake.shape
# Out:
# (1908310, 13)

# %% [markdown]
# # Borramos los nulos

# %%
mag_max_1.dropna(inplace=True)
# Out:
# C:\Users\juseb\AppData\Local\Temp\ipykernel_4372\105487757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mag_max_1.dropna(inplace=True)

# %%
mag_max_1.shape
# Out:
# (639152, 13)

# %% [markdown]
# # Guardamos el CSV

# %%
#original
df.to_csv('Salida2.csv')

# %%
mag_max_1.to_csv('Salida3.csv')

# %%
mag_max_1.head()
# Out:
#                        time  ...        type
# 1  1950-01-29T05:21:16.030Z  ...  earthquake
# 2  1950-01-28T22:45:12.670Z  ...  earthquake
# 3  1950-01-28T22:36:21.460Z  ...  earthquake
# 4  1950-01-28T12:10:04.690Z  ...  earthquake
# 5  1950-01-28T07:42:38.200Z  ...  earthquake
#
# [5 rows x 13 columns]
